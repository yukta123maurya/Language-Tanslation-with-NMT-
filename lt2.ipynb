# %%
try:
   # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
tf.executing_eagerly()
# Out:
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7a85cdf-9207-4662-a772-f3c7550f7f26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7a85cdf-9207-4662-a772-f3c7550f7f26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hin.txt to hin.txt

# %%
# Download the file
path_to_file = "hin.txt"
import os
print(os.listdir("."))
# Out:
# ['.config', 'hin.txt', 'sample_data']

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z\u0900-\u097f?.!,¿]+", " ", w)
#\u0900-\u097f
  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
en_sentence = u"Help!"
hi_sentence = u"बचाओ!"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(hi_sentence))#.encode('utf-8'))
# Out:
# <start> help ! <end>
# <start> बचाओ ! <end>

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, HINDI]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')
  print(lines[1])
 

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]


  return zip(*word_pairs)

# %%
hi,en = create_dataset(path_to_file, None)
print(en[1])
print(hi[1])
print(hi[5:])
# Out:
# Help!	बचाओ!	CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #459377 (minshirui)
# <start> बचाओ ! <end>
# <start> help ! <end>
# ('<start> hello ! <end>', '<start> hello ! <end>', '<start> cheers ! <end>', '<start> cheers ! <end>', '<start> got it ? <end>', '<start> i m ok . <end>', '<start> awesome ! <end>', '<start> come in . <end>', '<start> get out ! <end>', '<start> go away ! <end>', '<start> goodbye ! <end>', '<start> perfect ! <end>', '<start> perfect ! <end>', '<start> welcome . <end>', '<start> welcome . <end>', '<start> have fun . <end>', '<start> have fun . <end>', '<start> have fun . <end>', '<start> i forgot . <end>', '<start> i forgot . <end>', '<start> i ll pay . <end>', '<start> i m fine . <end>', '<start> i m full . <end>', '<start> let s go ! <end>', '<start> answer me . <end>', '<start> birds fly . <end>', '<start> excuse me . <end>', '<start> fantastic ! <end>', '<start> i fainted . <end>', '<start> i fear so . <end>', '<start> i laughed . <end>', '<start> i m bored . <end>', '<start> i m broke . <end>', '<start> i m tired . <end>', '<start> it s cold . <end>', '<start> well done ! <end>', '<start> who knows ? <end>', '<start> who knows ? <end>', '<start> who knows ? <end>', '<start> who knows ? <end>', '<start> wonderful ! <end>', '<start> birds sing . <end>', '<start> come on in . <end>', '<start> definitely ! <end>', '<start> don t move . <end>', '<start> fire burns . <end>', '<start> follow him . <end>', '<start> i can swim . <end>', '<start> i can swim . <end>', '<start> i love you . <end>', '<start> i love you . <end>', '<start> i love you . <end>', '<start> i love you . <end>', '<start> i love you . <end>', '<start> i will try . <end>', '<start> i m coming . <end>', '<start> i m hungry ! <end>', '<start> i m hungry ! <end>', '<start> let him in . <end>', '<start> let him in . <end>', '<start> let me out ! <end>', '<start> once again . <end>', '<start> please sit . <end>', '<start> that a boy ! <end>', '<start> what s new ? <end>', '<start> what s new ? <end>', '<start> who s that ? <end>', '<start> don t shout . <end>', '<start> don t shout . <end>', '<start> he stood up . <end>', '<start> he s strong . <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> how are you ? <end>', '<start> i like both . <end>', '<start> i like cake . <end>', '<start> i like dogs . <end>', '<start> i like math . <end>', '<start> i ll attend . <end>', '<start> nobody came . <end>', '<start> was i wrong ? <end>', '<start> what s this ? <end>', '<start> are you sick ? <end>', '<start> bring him in . <end>', '<start> come with us . <end>', '<start> happy easter ! <end>', '<start> has tom left ? <end>', '<start> i am at home . <end>', '<start> i can t move . <end>', '<start> i don t know . <end>', '<start> i don t know . <end>', '<start> i have a car . <end>', '<start> i have a dog . <end>', '<start> i understand . <end>', '<start> i m a doctor . <end>', '<start> it is a book . <end>', '<start> it s snowing . <end>', '<start> it s too big . <end>', '<start> please leave . <end>', '<start> unbelievable ! <end>', '<start> we are happy . <end>', '<start> what is this ? <end>', '<start> are you tired ? <end>', '<start> can you drive ? <end>', '<start> don t get fat . <end>', '<start> don t give in . <end>', '<start> drink it down . <end>', '<start> everyone dies . <end>', '<start> flowers bloom . <end>', '<start> i am who i am . <end>', '<start> i ll take him . <end>', '<start> i m tired now . <end>', '<start> i m very busy . <end>', '<start> is that a cat ? <end>', '<start> it s for free . <end>', '<start> it s for free . <end>', '<start> let me try it . <end>', '<start> let me try it . <end>', '<start> let me try it . <end>', '<start> make it quick . <end>', '<start> may i come in ? <end>', '<start> open the door . <end>', '<start> open the door . <end>', '<start> please get in . <end>', '<start> read it again . <end>', '<start> read it aloud . <end>', '<start> she bent down . <end>', '<start> some fish fly  ...

# %%
def tokenize(lang, split=None):
  if split== None:
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  else:
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
     filters='')

  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  inp_lang, targ_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang, split=" ")
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
num_examples = 300000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]
# Out:
# Help!	बचाओ!	CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #459377 (minshirui)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 2222 2222 556 556

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 17 ----> she
# 9 ----> is
# 10 ----> a
# 594 ----> woman
# 12 ----> of
# 631 ----> great
# 556 ----> beauty
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 8 ----> वह
# 20 ----> एक
# 16 ----> बहत
# 46 ----> ही
# 875 ----> खबसरत
# 554 ----> औरत
# 3 ----> ह।
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 128
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 700
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([128, 28]), TensorShape([128, 29]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences= True,
                                   return_state= True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (128, 28, 700)
# Encoder Hidden state shape: (batch size, units) (128, 700)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (128, 700)
# Attention weights shape: (batch_size, sequence_length, 1) (128, 28, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (128, 2720)

# %% [markdown]
# **Define the optimizer and the loss function**

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# **Checkpoints (Object-based saving)**

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 500

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.3201
# Epoch 1 Loss 1.8537
# Time taken for 1 epoch 47.17114043235779 sec
#
# Epoch 2 Batch 0 Loss 1.6641
# Epoch 2 Loss 1.6244
# Time taken for 1 epoch 2.9243597984313965 sec
#
# Epoch 3 Batch 0 Loss 1.5758
# Epoch 3 Loss 1.5588
# Time taken for 1 epoch 2.6961212158203125 sec
#
# Epoch 4 Batch 0 Loss 1.3951
# Epoch 4 Loss 1.4834
# Time taken for 1 epoch 2.8892369270324707 sec
#
# Epoch 5 Batch 0 Loss 1.3757
# Epoch 5 Loss 1.4082
# Time taken for 1 epoch 2.7191431522369385 sec
#
# Epoch 6 Batch 0 Loss 1.2966
# Epoch 6 Loss 1.3545
# Time taken for 1 epoch 5.3286590576171875 sec
#
# Epoch 7 Batch 0 Loss 1.4057
# Epoch 7 Loss 1.3086
# Time taken for 1 epoch 2.7302606105804443 sec
#
# Epoch 8 Batch 0 Loss 1.2845
# Epoch 8 Loss 1.2683
# Time taken for 1 epoch 2.891752243041992 sec
#
# Epoch 9 Batch 0 Loss 1.2211
# Epoch 9 Loss 1.2293
# Time taken for 1 epoch 2.7079598903656006 sec
#
# Epoch 10 Batch 0 Loss 1.1424
# Epoch 10 Loss 1.1870
# Time taken for 1 epoch 2.9150872230529785 sec
#
# Epoch 11 Batch 0 Loss 1.2135
# Epoch 11 Loss 1.1502
# Time taken for 1 epoch 2.6931047439575195 sec
#
# Epoch 12 Batch 0 Loss 1.1138
# Epoch 12 Loss 1.1119
# Time taken for 1 epoch 2.918752431869507 sec
#
# Epoch 13 Batch 0 Loss 1.0701
# Epoch 13 Loss 1.0741
# Time taken for 1 epoch 2.700515031814575 sec
#
# Epoch 14 Batch 0 Loss 1.0353
# Epoch 14 Loss 1.0417
# Time taken for 1 epoch 2.96474027633667 sec
#
# Epoch 15 Batch 0 Loss 0.9639
# Epoch 15 Loss 1.0070
# Time taken for 1 epoch 2.6997995376586914 sec
#
# Epoch 16 Batch 0 Loss 1.0217
# Epoch 16 Loss 0.9696
# Time taken for 1 epoch 2.878079891204834 sec
#
# Epoch 17 Batch 0 Loss 0.9094
# Epoch 17 Loss 0.9376
# Time taken for 1 epoch 2.7031919956207275 sec
#
# Epoch 18 Batch 0 Loss 0.8597
# Epoch 18 Loss 0.9053
# Time taken for 1 epoch 2.875734567642212 sec
#
# Epoch 19 Batch 0 Loss 0.9044
# Epoch 19 Loss 0.8721
# Time taken for 1 epoch 2.6914525032043457 sec
#
# Epoch 20 Batch 0 Loss 0.8594
# Epoch 20 Loss 0.8371
# Time taken for 1 epoch 2.920170545578003 sec
#
# Epoch 21 Batch 0 Loss 0.8011
# Epoch 21 Loss 0.8023
# Time taken for 1 epoch 2.725260019302368 sec
#
# Epoch 22 Batch 0 Loss 0.7489
# Epoch 22 Loss 0.7702
# Time taken for 1 epoch 2.9229788780212402 sec
#
# Epoch 23 Batch 0 Loss 0.7120
# Epoch 23 Loss 0.7409
# Time taken for 1 epoch 2.7256689071655273 sec
#
# Epoch 24 Batch 0 Loss 0.6550
# Epoch 24 Loss 0.7094
# Time taken for 1 epoch 2.940859794616699 sec
#
# Epoch 25 Batch 0 Loss 0.6409
# Epoch 25 Loss 0.6748
# Time taken for 1 epoch 2.7100272178649902 sec
#
# Epoch 26 Batch 0 Loss 0.6195
# Epoch 26 Loss 0.6445
# Time taken for 1 epoch 2.9012608528137207 sec
#
# Epoch 27 Batch 0 Loss 0.5786
# Epoch 27 Loss 0.6156
# Time taken for 1 epoch 2.685351848602295 sec
#
# Epoch 28 Batch 0 Loss 0.5746
# Epoch 28 Loss 0.5856
# Time taken for 1 epoch 2.936189889907837 sec
#
# Epoch 29 Batch 0 Loss 0.5091
# Epoch 29 Loss 0.5564
# Time taken for 1 epoch 2.719841241836548 sec
#
# Epoch 30 Batch 0 Loss 0.4889
# Epoch 30 Loss 0.5314
# Time taken for 1 epoch 2.9124412536621094 sec
#
# Epoch 31 Batch 0 Loss 0.5138
# Epoch 31 Loss 0.5025
# Time taken for 1 epoch 2.711448907852173 sec
#
# Epoch 32 Batch 0 Loss 0.4580
# Epoch 32 Loss 0.4755
# Time taken for 1 epoch 2.8934128284454346 sec
#
# Epoch 33 Batch 0 Loss 0.4288
# Epoch 33 Loss 0.4486
# Time taken for 1 epoch 2.695591688156128 sec
#
# Epoch 34 Batch 0 Loss 0.4326
# Epoch 34 Loss 0.4241
# Time taken for 1 epoch 2.9055442810058594 sec
#
# Epoch 35 Batch 0 Loss 0.3733
# Epoch 35 Loss 0.4018
# Time taken for 1 epoch 2.726811647415161 sec
#
# Epoch 36 Batch 0 Loss 0.3883
# Epoch 36 Loss 0.3768
# Time taken for 1 epoch 2.8934874534606934 sec
#
# Epoch 37 Batch 0 Loss 0.3244
# Epoch 37 Loss 0.3588
# Time taken for 1 epoch 2.689462900161743 sec
#
# Epoch 38 Batch 0 Loss 0.3229
# Epoch 38 Loss 0.3425
# Time taken for 1 epoch 2.9051430225372314 sec
#
# Epoch 39 Batch 0 Loss 0.3165
# Epoch 39 Loss 0.3252
# Time taken for 1 epoch 2.724982738494873 sec
#
# Epoch 40 Batch 0 Loss 0.2900
# Epoch 40 Loss 0.3019
# Time taken for 1 epoch 2.9115192890167236 sec
#
# Epoch 41 Batch 0 Loss 0.2513
# Epoch 41 Loss 0.2787
# Time taken for 1 epoch 2.699162483215332 sec
#
# Epoch 42 Batch 0 Loss 0.2514
# Epoch 42 Loss 0.2598
# Time taken for 1 epoch 2.8970727920532227 sec
#
# Epoch 43 Batch 0 Loss 0.2541
# Epoch 43 Loss 0.2409
# Time taken for 1 epoch 2.698289632797241 sec
#
# Epoch 44 Batch 0 Loss 0.2217
# Epoch 44 Loss 0.2222
# Time taken for 1 epoch 2.935284376144409 sec
#
# Epoch 45 Batch 0 Loss 0.2066
# Epoch 45 Loss 0.2066
# Time taken for 1 epoch 2.692054510116577 sec
#
# Epoch 46 Batch 0 Loss 0.1789
# Epoch 46 Loss 0.1908
# Time taken for 1 epoch 2.903887987136841 sec
#
# Epoch 47 Batch 0 Loss 0.1835
# Epoch 47 Loss 0.1758
# Time taken for 1 epoch 2.715947389602661 sec
#
# Epoch 48 Batch 0 Loss 0.1524
# Epoch 48 Loss 0.1631
# Time taken for 1 epoch 2.8968584537506104 sec
#
# Epoch 49 Batch 0 Loss 0.1297
# Epoch 49 Loss 0.1517
# Time taken for 1 epoch 2.7083523273468018 sec
#
# Epoch 50 Batch 0 Loss 0.1321
# Epoch 50 Loss 0.1420
# Time taken for 1 epoch 2.904928207397461 sec
#
# Epoch 51 Batch 0 Loss 0.1079
# Epoch 51 Loss 0.1293
# Time taken for 1 epoch 2.7050669193267822 sec
#
# Epoch 52 Batch 0 Loss 0.1125
# Epoch 52 Loss 0.1190
# Time taken for 1 epoch 2.91739821434021 sec
#
# Epoch 53 Batch 0 Loss 0.0953
# Epoch 53 Loss 0.1094
# Time taken for 1 epoch 2.693206548690796 sec
#
# Epoch 54 Batch 0 Loss 0.1009
# Epoch 54 Loss 0.1004
# Time taken for 1 epoch 2.901987314224243 sec
#
# Epoch 55 Batch 0 Loss 0.0857
# Epoch 55 Loss 0.0921
# Time taken for 1 epoch 2.6935842037200928 sec
#
# Epoch 56 Batch 0 Loss 0.0740
# Epoch 56 Loss 0.0839
# Time taken for 1 epoch 2.9204962253570557 sec
#
# Epoch 57 Batch 0 Loss 0.0768
# Epoch 57 Loss 0.0764
# Time taken for 1 epoch 2.707256317138672 sec
#
# Epoch 58 Batch 0 Loss 0.0557
# Epoch 58 Loss 0.0697
# Time taken for 1 epoch 2.942673921585083 sec
#
# Epoch 59 Batch 0 Loss 0.0624
# Epoch 59 Loss 0.0633
# Time taken for 1 epoch 2.709298849105835 sec
#
# Epoch 60 Batch 0 Loss 0.0591
# Epoch 60 Loss 0.0572
# Time taken for 1 epoch 2.917329788208008 sec
#
# Epoch 61 Batch 0 Loss 0.0511
# Epoch 61 Loss 0.0519
# Time taken for 1 epoch 2.7207226753234863 sec
#
# Epoch 62 Batch 0 Loss 0.0413
# Epoch 62 Loss 0.0472
# Time taken for 1 epoch 2.901320457458496 sec
#
# Epoch 63 Batch 0 Loss 0.0338
# Epoch 63 Loss 0.0426
# Time taken for 1 epoch 2.7482824325561523 sec
#
# Epoch 64 Batch 0 Loss 0.0394
# Epoch 64 Loss 0.0392
# Time taken for 1 epoch 2.912835121154785 sec
#
# Epoch 65 Batch 0 Loss 0.0352
# Epoch 65 Loss 0.0356
# Time taken for 1 epoch 2.732678174972534 sec
#
# Epoch 66 Batch 0 Loss 0.0318
# Epoch 66 Loss 0.0330
# Time taken for 1 epoch 3.0315933227539062 sec
#
# Epoch 67 Batch 0 Loss 0.0305
# Epoch 67 Loss 0.0310
# Time taken for 1 epoch 2.733116865158081 sec
#
# Epoch 68 Batch 0 Loss 0.0257
# Epoch 68 Loss 0.0286
# Time taken for 1 epoch 2.8926258087158203 sec
#
# Epoch 69 Batch 0 Loss 0.0257
# Epoch 69 Loss 0.0269
# Time taken for 1 epoch 2.692256212234497 sec
#
# Epoch 70 Batch 0 Loss 0.0244
# Epoch 70 Loss 0.0253
# Time taken for 1 epoch 3.03580379486084 sec
#
# Epoch 71 Batch 0 Loss 0.0203
# Epoch 71 Loss 0.0236
# Time taken for 1 epoch 2.6934354305267334 sec
#
# Epoch 72 Batch 0 Loss 0.0196
# Epoch 72 Loss 0.0226
# Time taken for 1 epoch 2.9079482555389404 sec
#
# Epoch 73 Batch 0 Loss 0.0191
# Epoch 73 Loss 0.0215
# Time taken for 1 epoch 2.7178995609283447 sec
#
# Epoch 74 Batch 0 Loss 0.0193
# Epoch 74 Loss 0.0204
# Time taken for 1 epoch 2.985701322555542 sec
#
# Epoch 75 Batch 0 Loss 0.0198
# Epoch 75 Loss 0.0196
# Time taken for 1 epoch 2.692929744720459 sec
#
# Epoch 76 Batch 0 Loss 0.0156
# Epoch 76 Loss 0.0186
# Time taken for 1 epoch 2.91153883934021 sec
#
# Epoch 77 Batch 0 Loss 0.0183
# Epoch 77 Loss 0.0181
# Time taken for 1 epoch 2.746502637863159 sec
#
# Epoch 78 Batch 0 Loss 0.0166
# Epoch 78 Loss 0.0174
# Time taken for 1 epoch 2.910627603530884 sec
#
# Epoch 79 Batch 0 Loss 0.0150
# Epoch 79 Loss 0.0165
# Time taken for 1 epoch 2.7351462841033936 sec
#
# Epoch 80 Batch 0 Loss 0.0145
# Epoch 80 Loss 0.0160
# Time taken for 1 epoch 2.907132148742676 sec
#
# Epoch 81 Batch 0 Loss 0.0146
# Epoch 81 Loss 0.0156
# Time taken for 1 epoch 2.699320077896118 sec
#
# Epoch 82 Batch 0 Loss 0.0131
# Epoch 82 Loss 0.0148
# Time taken for 1 epoch 2.919194221496582 sec
#
# Epoch 83 Batch 0 Loss 0.0146
# Epoch 83 Loss 0.0145
# Time taken for 1 epoch 2.7023050785064697 sec
#
# Epoch 84 Batch 0 Loss 0.0116
# Epoch 84 Loss 0.0141
# Time taken for 1 epoch 2.909376621246338 sec
#
# Epoch 85 Batch 0 Loss 0.0123
# Epoch 85 Loss 0.0135
# Time taken for 1 epoch 2.715733289718628 sec
#
# Epoch 86 Batch 0 Loss 0.0106
# Epoch 86 Loss 0.0133
# Time taken for 1 epoch 2.933666229248047 sec
#
# Epoch 87 Batch 0 Loss 0.0095
# Epoch 87 Loss 0.0127
# Time taken for 1 epoch 2.7165191173553467 sec
#
# Epoch 88 Batch 0 Loss 0.0112
# Epoch 88 Loss 0.0123
# Time taken for 1 epoch 2.8951988220214844 sec
#
# Epoch 89 Batch 0 Loss 0.0098
# Epoch 89 Loss 0.0121
# Time taken for 1 epoch 2.724479913711548 sec
#
# Epoch 90 Batch 0 Loss 0.0105
# Epoch 90 Loss 0.0120
# Time taken for 1 epoch 2.936134099960327 sec
#
# Epoch 91 Batch 0 Loss 0.0092
# Epoch 91 Loss 0.0115
# Time taken for 1 epoch 2.7112948894500732 sec
#
# Epoch 92 Batch 0 Loss 0.0094
# Epoch 92 Loss 0.0113
# Time taken for 1 epoch 2.911004066467285 sec
#
# Epoch 93 Batch 0 Loss 0.0102
# Epoch 93 Loss 0.0112
# Time taken for 1 epoch 2.6907973289489746 sec
#
# Epoch 94 Batch 0 Loss 0.0099
# Epoch 94 Loss 0.0110
# Time taken for 1 epoch 2.9120850563049316 sec
#
# Epoch 95 Batch 0 Loss 0.0103
# Epoch 95 Loss 0.0108
# Time taken for 1 epoch 2.6825273036956787 sec
#
# Epoch 96 Batch 0 Loss 0.0119
# Epoch 96 Loss 0.0106
# Time taken for 1 epoch 2.994898557662964 sec
#
# Epoch 97 Batch 0 Loss 0.0088
# Epoch 97 Loss 0.0104
# Time taken for 1 epoch 2.6871094703674316 sec
#
# Epoch 98 Batch 0 Loss 0.0079
# Epoch 98 Loss 0.0104
# Time taken for 1 epoch 2.9043514728546143 sec
#
# Epoch 99 Batch 0 Loss 0.0097
# Epoch 99 Loss 0.0106
# Time taken for 1 epoch 2.7129151821136475 sec
#
# Epoch 100 Batch 0 Loss 0.0101
# Epoch 100 Loss 0.0101
# Time taken for 1 epoch 2.8926100730895996 sec
#
# Epoch 101 Batch 0 Loss 0.0094
# Epoch 101 Loss 0.0099
# Time taken for 1 epoch 2.68666410446167 sec
#
# Epoch 102 Batch 0 Loss 0.0086
# Epoch 102 Loss 0.0096
# Time taken for 1 epoch 2.919569730758667 sec
#
# Epoch 103 Batch 0 Loss 0.0070
# Epoch 103 Loss 0.0093
# Time taken for 1 epoch 2.727293014526367 sec
#
# Epoch 104 Batch 0 Loss 0.0078
# Epoch 104 Loss 0.0093
# Time taken for 1 epoch 2.9318435192108154 sec
#
# Epoch 105 Batch 0 Loss 0.0087
# Epoch 105 Loss 0.0091
# Time taken for 1 epoch 5.13045334815979 sec
#
# Epoch 106 Batch 0 Loss 0.0086
# Epoch 106 Loss 0.0091
# Time taken for 1 epoch 2.908036231994629 sec
#
# Epoch 107 Batch 0 Loss 0.0068
# Epoch 107 Loss 0.0089
# Time taken for 1 epoch 2.7157256603240967 sec
#
# Epoch 108 Batch 0 Loss 0.0066
# Epoch 108 Loss 0.0090
# Time taken for 1 epoch 2.9090235233306885 sec
#
# Epoch 109 Batch 0 Loss 0.0076
# Epoch 109 Loss 0.0104
# Time taken for 1 epoch 2.6933138370513916 sec
#
# Epoch 110 Batch 0 Loss 0.0113
# Epoch 110 Loss 0.0392
# Time taken for 1 epoch 2.9126510620117188 sec
#
# Epoch 111 Batch 0 Loss 0.0585
# Epoch 111 Loss 0.1100
# Time taken for 1 epoch 2.6851837635040283 sec
#
# Epoch 112 Batch 0 Loss 0.1189
# Epoch 112 Loss 0.1336
# Time taken for 1 epoch 2.948291063308716 sec
#
# Epoch 113 Batch 0 Loss 0.0829
# Epoch 113 Loss 0.0962
# Time taken for 1 epoch 2.722668409347534 sec
#
# Epoch 114 Batch 0 Loss 0.0571
# Epoch 114 Loss 0.0579
# Time taken for 1 epoch 2.9173293113708496 sec
#
# Epoch 115 Batch 0 Loss 0.0340
# Epoch 115 Loss 0.0321
# Time taken for 1 epoch 2.703979015350342 sec
#
# Epoch 116 Batch 0 Loss 0.0192
# Epoch 116 Loss 0.0199
# Time taken for 1 epoch 2.9265284538269043 sec
#
# Epoch 117 Batch 0 Loss 0.0123
# Epoch 117 Loss 0.0141
# Time taken for 1 epoch 2.6955034732818604 sec
#
# Epoch 118 Batch 0 Loss 0.0109
# Epoch 118 Loss 0.0121
# Time taken for 1 epoch 2.9138693809509277 sec
#
# Epoch 119 Batch 0 Loss 0.0094
# Epoch 119 Loss 0.0102
# Time taken for 1 epoch 2.726872444152832 sec
#
# Epoch 120 Batch 0 Loss 0.0087
# Epoch 120 Loss 0.0097
# Time taken for 1 epoch 2.9116058349609375 sec
#
# Epoch 121 Batch 0 Loss 0.0098
# Epoch 121 Loss 0.0090
# Time taken for 1 epoch 2.709646463394165 sec
#
# Epoch 122 Batch 0 Loss 0.0044
# Epoch 122 Loss 0.0087
# Time taken for 1 epoch 2.964303731918335 sec
#
# Epoch 123 Batch 0 Loss 0.0082
# Epoch 123 Loss 0.0086
# Time taken for 1 epoch 2.6993963718414307 sec
#
# Epoch 124 Batch 0 Loss 0.0055
# Epoch 124 Loss 0.0082
# Time taken for 1 epoch 2.9440066814422607 sec
#
# Epoch 125 Batch 0 Loss 0.0081
# Epoch 125 Loss 0.0080
# Time taken for 1 epoch 2.7084767818450928 sec
#
# Epoch 126 Batch 0 Loss 0.0062
# Epoch 126 Loss 0.0079
# Time taken for 1 epoch 2.9155433177948 sec
#
# Epoch 127 Batch 0 Loss 0.0053
# Epoch 127 Loss 0.0079
# Time taken for 1 epoch 2.7289834022521973 sec
#
# Epoch 128 Batch 0 Loss 0.0086
# Epoch 128 Loss 0.0079
# Time taken for 1 epoch 2.9882009029388428 sec
#
# Epoch 129 Batch 0 Loss 0.0086
# Epoch 129 Loss 0.0077
# Time taken for 1 epoch 2.681891679763794 sec
#
# Epoch 130 Batch 0 Loss 0.0060
# Epoch 130 Loss 0.0076
# Time taken for 1 epoch 2.963632822036743 sec
#
# Epoch 131 Batch 0 Loss 0.0080
# Epoch 131 Loss 0.0074
# Time taken for 1 epoch 2.6843478679656982 sec
#
# Epoch 132 Batch 0 Loss 0.0069
# Epoch 132 Loss 0.0076
# Time taken for 1 epoch 2.954007148742676 sec
#
# Epoch 133 Batch 0 Loss 0.0061
# Epoch 133 Loss 0.0074
# Time taken for 1 epoch 2.7171716690063477 sec
#
# Epoch 134 Batch 0 Loss 0.0040
# Epoch 134 Loss 0.0071
# Time taken for 1 epoch 2.9568769931793213 sec
#
# Epoch 135 Batch 0 Loss 0.0052
# Epoch 135 Loss 0.0073
# Time taken for 1 epoch 2.7286832332611084 sec
#
# Epoch 136 Batch 0 Loss 0.0061
# Epoch 136 Loss 0.0071
# Time taken for 1 epoch 2.898141384124756 sec
#
# Epoch 137 Batch 0 Loss 0.0081
# Epoch 137 Loss 0.0071
# Time taken for 1 epoch 2.7301647663116455 sec
#
# Epoch 138 Batch 0 Loss 0.0063
# Epoch 138 Loss 0.0070
# Time taken for 1 epoch 2.895047426223755 sec
#
# Epoch 139 Batch 0 Loss 0.0050
# Epoch 139 Loss 0.0067
# Time taken for 1 epoch 2.6980702877044678 sec
#
# Epoch 140 Batch 0 Loss 0.0041
# Epoch 140 Loss 0.0067
# Time taken for 1 epoch 2.973506212234497 sec
#
# Epoch 141 Batch 0 Loss 0.0059
# Epoch 141 Loss 0.0070
# Time taken for 1 epoch 2.7386927604675293 sec
#
# Epoch 142 Batch 0 Loss 0.0049
# Epoch 142 Loss 0.0066
# Time taken for 1 epoch 3.005748987197876 sec
#
# Epoch 143 Batch 0 Loss 0.0053
# Epoch 143 Loss 0.0066
# Time taken for 1 epoch 2.6893367767333984 sec
#
# Epoch 144 Batch 0 Loss 0.0054
# Epoch 144 Loss 0.0068
# Time taken for 1 epoch 2.8936641216278076 sec
#
# Epoch 145 Batch 0 Loss 0.0053
# Epoch 145 Loss 0.0065
# Time taken for 1 epoch 2.719454765319824 sec
#
# Epoch 146 Batch 0 Loss 0.0063
# Epoch 146 Loss 0.0067
# Time taken for 1 epoch 2.953106641769409 sec
#
# Epoch 147 Batch 0 Loss 0.0069
# Epoch 147 Loss 0.0068
# Time taken for 1 epoch 2.7093589305877686 sec
#
# Epoch 148 Batch 0 Loss 0.0061
# Epoch 148 Loss 0.0068
# Time taken for 1 epoch 2.947666645050049 sec
#
# Epoch 149 Batch 0 Loss 0.0045
# Epoch 149 Loss 0.0064
# Time taken for 1 epoch 2.721879720687866 sec
#
# Epoch 150 Batch 0 Loss 0.0071
# Epoch 150 Loss 0.0066
# Time taken for 1 epoch 2.9641335010528564 sec
#
# Epoch 151 Batch 0 Loss 0.0054
# Epoch 151 Loss 0.0065
# Time taken for 1 epoch 2.7044503688812256 sec
#
# Epoch 152 Batch 0 Loss 0.0052
# Epoch 152 Loss 0.0067
# Time taken for 1 epoch 2.920346975326538 sec
#
# Epoch 153 Batch 0 Loss 0.0051
# Epoch 153 Loss 0.0067
# Time taken for 1 epoch 2.7000975608825684 sec
#
# Epoch 154 Batch 0 Loss 0.0054
# Epoch 154 Loss 0.0065
# Time taken for 1 epoch 2.9554450511932373 sec
#
# Epoch 155 Batch 0 Loss 0.0060
# Epoch 155 Loss 0.0065
# Time taken for 1 epoch 2.732647657394409 sec
#
# Epoch 156 Batch 0 Loss 0.0048
# Epoch 156 Loss 0.0062
# Time taken for 1 epoch 2.92771577835083 sec
#
# Epoch 157 Batch 0 Loss 0.0056
# Epoch 157 Loss 0.0062
# Time taken for 1 epoch 2.7211267948150635 sec
#
# Epoch 158 Batch 0 Loss 0.0071
# Epoch 158 Loss 0.0063
# Time taken for 1 epoch 2.9480741024017334 sec
#
# Epoch 159 Batch 0 Loss 0.0047
# Epoch 159 Loss 0.0063
# Time taken for 1 epoch 2.7087337970733643 sec
#
# Epoch 160 Batch 0 Loss 0.0046
# Epoch 160 Loss 0.0062
# Time taken for 1 epoch 2.978208303451538 sec
#
# Epoch 161 Batch 0 Loss 0.0034
# Epoch 161 Loss 0.0059
# Time taken for 1 epoch 2.7148008346557617 sec
#
# Epoch 162 Batch 0 Loss 0.0044
# Epoch 162 Loss 0.0060
# Time taken for 1 epoch 2.9461288452148438 sec
#
# Epoch 163 Batch 0 Loss 0.0040
# Epoch 163 Loss 0.0062
# Time taken for 1 epoch 2.7144992351531982 sec
#
# Epoch 164 Batch 0 Loss 0.0051
# Epoch 164 Loss 0.0061
# Time taken for 1 epoch 2.9404263496398926 sec
#
# Epoch 165 Batch 0 Loss 0.0057
# Epoch 165 Loss 0.0058
# Time taken for 1 epoch 2.704533338546753 sec
#
# Epoch 166 Batch 0 Loss 0.0070
# Epoch 166 Loss 0.0061
# Time taken for 1 epoch 2.919628620147705 sec
#
# Epoch 167 Batch 0 Loss 0.0042
# Epoch 167 Loss 0.0060
# Time taken for 1 epoch 2.7077198028564453 sec
#
# Epoch 168 Batch 0 Loss 0.0050
# Epoch 168 Loss 0.0060
# Time taken for 1 epoch 2.903102159500122 sec
#
# Epoch 169 Batch 0 Loss 0.0038
# Epoch 169 Loss 0.0060
# Time taken for 1 epoch 2.700803756713867 sec
#
# Epoch 170 Batch 0 Loss 0.0059
# Epoch 170 Loss 0.0062
# Time taken for 1 epoch 2.964686155319214 sec
#
# Epoch 171 Batch 0 Loss 0.0044
# Epoch 171 Loss 0.0059
# Time taken for 1 epoch 2.703223943710327 sec
#
# Epoch 172 Batch 0 Loss 0.0047
# Epoch 172 Loss 0.0059
# Time taken for 1 epoch 2.8902721405029297 sec
#
# Epoch 173 Batch 0 Loss 0.0036
# Epoch 173 Loss 0.0059
# Time taken for 1 epoch 5.1127378940582275 sec
#
# Epoch 174 Batch 0 Loss 0.0041
# Epoch 174 Loss 0.0061
# Time taken for 1 epoch 5.4066314697265625 sec
#
# Epoch 175 Batch 0 Loss 0.0057
# Epoch 175 Loss 0.0061
# Time taken for 1 epoch 2.703526258468628 sec
#
# Epoch 176 Batch 0 Loss 0.0044
# Epoch 176 Loss 0.0059
# Time taken for 1 epoch 2.9253180027008057 sec
#
# Epoch 177 Batch 0 Loss 0.0060
# Epoch 177 Loss 0.0059
# Time taken for 1 epoch 2.7362866401672363 sec
#
# Epoch 178 Batch 0 Loss 0.0051
# Epoch 178 Loss 0.0059
# Time taken for 1 epoch 2.9509479999542236 sec
#
# Epoch 179 Batch 0 Loss 0.0057
# Epoch 179 Loss 0.0061
# Time taken for 1 epoch 2.692780017852783 sec
#
# Epoch 180 Batch 0 Loss 0.0035
# Epoch 180 Loss 0.0061
# Time taken for 1 epoch 2.9162425994873047 sec
#
# Epoch 181 Batch 0 Loss 0.0054
# Epoch 181 Loss 0.0068
# Time taken for 1 epoch 2.7473268508911133 sec
#
# Epoch 182 Batch 0 Loss 0.0036
# Epoch 182 Loss 0.0075
# Time taken for 1 epoch 2.9206435680389404 sec
#
# Epoch 183 Batch 0 Loss 0.0045
# Epoch 183 Loss 0.0107
# Time taken for 1 epoch 2.7065746784210205 sec
#
# Epoch 184 Batch 0 Loss 0.0084
# Epoch 184 Loss 0.0125
# Time taken for 1 epoch 2.894132137298584 sec
#
# Epoch 185 Batch 0 Loss 0.0091
# Epoch 185 Loss 0.0169
# Time taken for 1 epoch 2.7238337993621826 sec
#
# Epoch 186 Batch 0 Loss 0.0125
# Epoch 186 Loss 0.0177
# Time taken for 1 epoch 2.942371129989624 sec
#
# Epoch 187 Batch 0 Loss 0.0106
# Epoch 187 Loss 0.0176
# Time taken for 1 epoch 2.7107627391815186 sec
#
# Epoch 188 Batch 0 Loss 0.0184
# Epoch 188 Loss 0.0191
# Time taken for 1 epoch 2.9868547916412354 sec
#
# Epoch 189 Batch 0 Loss 0.0144
# Epoch 189 Loss 0.0180
# Time taken for 1 epoch 2.6999013423919678 sec
#
# Epoch 190 Batch 0 Loss 0.0107
# Epoch 190 Loss 0.0157
# Time taken for 1 epoch 2.970306396484375 sec
#
# Epoch 191 Batch 0 Loss 0.0093
# Epoch 191 Loss 0.0137
# Time taken for 1 epoch 2.701864719390869 sec
#
# Epoch 192 Batch 0 Loss 0.0100
# Epoch 192 Loss 0.0119
# Time taken for 1 epoch 2.9273486137390137 sec
#
# Epoch 193 Batch 0 Loss 0.0089
# Epoch 193 Loss 0.0118
# Time taken for 1 epoch 2.7278618812561035 sec
#
# Epoch 194 Batch 0 Loss 0.0069
# Epoch 194 Loss 0.0102
# Time taken for 1 epoch 2.9076569080352783 sec
#
# Epoch 195 Batch 0 Loss 0.0076
# Epoch 195 Loss 0.0090
# Time taken for 1 epoch 2.7286903858184814 sec
#
# Epoch 196 Batch 0 Loss 0.0061
# Epoch 196 Loss 0.0079
# Time taken for 1 epoch 3.0109915733337402 sec
#
# Epoch 197 Batch 0 Loss 0.0038
# Epoch 197 Loss 0.0071
# Time taken for 1 epoch 2.71012544631958 sec
#
# Epoch 198 Batch 0 Loss 0.0075
# Epoch 198 Loss 0.0066
# Time taken for 1 epoch 2.9009103775024414 sec
#
# Epoch 199 Batch 0 Loss 0.0041
# Epoch 199 Loss 0.0063
# Time taken for 1 epoch 2.7347171306610107 sec
#
# Epoch 200 Batch 0 Loss 0.0045
# Epoch 200 Loss 0.0062
# Time taken for 1 epoch 2.9355649948120117 sec
#
# Epoch 201 Batch 0 Loss 0.0048
# Epoch 201 Loss 0.0060
# Time taken for 1 epoch 2.715163230895996 sec
#
# Epoch 202 Batch 0 Loss 0.0042
# Epoch 202 Loss 0.0059
# Time taken for 1 epoch 2.976332426071167 sec
#
# Epoch 203 Batch 0 Loss 0.0032
# Epoch 203 Loss 0.0058
# Time taken for 1 epoch 2.695935010910034 sec
#
# Epoch 204 Batch 0 Loss 0.0042
# Epoch 204 Loss 0.0058
# Time taken for 1 epoch 2.953418016433716 sec
#
# Epoch 205 Batch 0 Loss 0.0064
# Epoch 205 Loss 0.0060
# Time taken for 1 epoch 2.6987757682800293 sec
#
# Epoch 206 Batch 0 Loss 0.0047
# Epoch 206 Loss 0.0058
# Time taken for 1 epoch 2.9070489406585693 sec
#
# Epoch 207 Batch 0 Loss 0.0045
# Epoch 207 Loss 0.0056
# Time taken for 1 epoch 2.6861634254455566 sec
#
# Epoch 208 Batch 0 Loss 0.0060
# Epoch 208 Loss 0.0056
# Time taken for 1 epoch 2.95332670211792 sec
#
# Epoch 209 Batch 0 Loss 0.0052
# Epoch 209 Loss 0.0055
# Time taken for 1 epoch 2.7200632095336914 sec
#
# Epoch 210 Batch 0 Loss 0.0047
# Epoch 210 Loss 0.0056
# Time taken for 1 epoch 2.8938465118408203 sec
#
# Epoch 211 Batch 0 Loss 0.0071
# Epoch 211 Loss 0.0055
# Time taken for 1 epoch 2.7105178833007812 sec
#
# Epoch 212 Batch 0 Loss 0.0043
# Epoch 212 Loss 0.0053
# Time taken for 1 epoch 2.928455114364624 sec
#
# Epoch 213 Batch 0 Loss 0.0057
# Epoch 213 Loss 0.0055
# Time taken for 1 epoch 2.6871695518493652 sec
#
# Epoch 214 Batch 0 Loss 0.0046
# Epoch 214 Loss 0.0053
# Time taken for 1 epoch 3.026285409927368 sec
#
# Epoch 215 Batch 0 Loss 0.0056
# Epoch 215 Loss 0.0054
# Time taken for 1 epoch 2.7005624771118164 sec
#
# Epoch 216 Batch 0 Loss 0.0034
# Epoch 216 Loss 0.0056
# Time taken for 1 epoch 2.9641764163970947 sec
#
# Epoch 217 Batch 0 Loss 0.0042
# Epoch 217 Loss 0.0055
# Time taken for 1 epoch 2.727715492248535 sec
#
# Epoch 218 Batch 0 Loss 0.0054
# Epoch 218 Loss 0.0056
# Time taken for 1 epoch 2.9077234268188477 sec
#
# Epoch 219 Batch 0 Loss 0.0063
# Epoch 219 Loss 0.0054
# Time taken for 1 epoch 2.688950300216675 sec
#
# Epoch 220 Batch 0 Loss 0.0049
# Epoch 220 Loss 0.0053
# Time taken for 1 epoch 2.96281099319458 sec
#
# Epoch 221 Batch 0 Loss 0.0045
# Epoch 221 Loss 0.0052
# Time taken for 1 epoch 2.69250226020813 sec
#
# Epoch 222 Batch 0 Loss 0.0033
# Epoch 222 Loss 0.0053
# Time taken for 1 epoch 2.940326452255249 sec
#
# Epoch 223 Batch 0 Loss 0.0064
# Epoch 223 Loss 0.0052
# Time taken for 1 epoch 2.718885660171509 sec
#
# Epoch 224 Batch 0 Loss 0.0025
# Epoch 224 Loss 0.0052
# Time taken for 1 epoch 2.9291083812713623 sec
#
# Epoch 225 Batch 0 Loss 0.0033
# Epoch 225 Loss 0.0054
# Time taken for 1 epoch 2.7054717540740967 sec
#
# Epoch 226 Batch 0 Loss 0.0045
# Epoch 226 Loss 0.0055
# Time taken for 1 epoch 2.9676594734191895 sec
#
# Epoch 227 Batch 0 Loss 0.0032
# Epoch 227 Loss 0.0055
# Time taken for 1 epoch 2.700627088546753 sec
#
# Epoch 228 Batch 0 Loss 0.0042
# Epoch 228 Loss 0.0054
# Time taken for 1 epoch 3.0003373622894287 sec
#
# Epoch 229 Batch 0 Loss 0.0049
# Epoch 229 Loss 0.0053
# Time taken for 1 epoch 2.6893277168273926 sec
#
# Epoch 230 Batch 0 Loss 0.0057
# Epoch 230 Loss 0.0055
# Time taken for 1 epoch 2.9984261989593506 sec
#
# Epoch 231 Batch 0 Loss 0.0030
# Epoch 231 Loss 0.0052
# Time taken for 1 epoch 2.7310171127319336 sec
#
# Epoch 232 Batch 0 Loss 0.0028
# Epoch 232 Loss 0.0053
# Time taken for 1 epoch 2.9450273513793945 sec
#
# Epoch 233 Batch 0 Loss 0.0052
# Epoch 233 Loss 0.0053
# Time taken for 1 epoch 2.683387279510498 sec
#
# Epoch 234 Batch 0 Loss 0.0050
# Epoch 234 Loss 0.0054
# Time taken for 1 epoch 3.0145390033721924 sec
#
# Epoch 235 Batch 0 Loss 0.0031
# Epoch 235 Loss 0.0052
# Time taken for 1 epoch 2.6968929767608643 sec
#
# Epoch 236 Batch 0 Loss 0.0035
# Epoch 236 Loss 0.0049
# Time taken for 1 epoch 2.9008986949920654 sec
#
# Epoch 237 Batch 0 Loss 0.0020
# Epoch 237 Loss 0.0051
# Time taken for 1 epoch 2.728998899459839 sec
#
# Epoch 238 Batch 0 Loss 0.0028
# Epoch 238 Loss 0.0052
# Time taken for 1 epoch 2.9917361736297607 sec
#
# Epoch 239 Batch 0 Loss 0.0034
# Epoch 239 Loss 0.0050
# Time taken for 1 epoch 2.6951990127563477 sec
#
# Epoch 240 Batch 0 Loss 0.0046
# Epoch 240 Loss 0.0054
# Time taken for 1 epoch 3.093315362930298 sec
#
# Epoch 241 Batch 0 Loss 0.0049
# Epoch 241 Loss 0.0052
# Time taken for 1 epoch 2.705972671508789 sec
#
# Epoch 242 Batch 0 Loss 0.0044
# Epoch 242 Loss 0.0051
# Time taken for 1 epoch 2.9440736770629883 sec
#
# Epoch 243 Batch 0 Loss 0.0053
# Epoch 243 Loss 0.0054
# Time taken for 1 epoch 2.6935482025146484 sec
#
# Epoch 244 Batch 0 Loss 0.0050
# Epoch 244 Loss 0.0054
# Time taken for 1 epoch 2.986132860183716 sec
#
# Epoch 245 Batch 0 Loss 0.0044
# Epoch 245 Loss 0.0050
# Time taken for 1 epoch 2.7139925956726074 sec
#
# Epoch 246 Batch 0 Loss 0.0040
# Epoch 246 Loss 0.0052
# Time taken for 1 epoch 2.941507577896118 sec
#
# Epoch 247 Batch 0 Loss 0.0038
# Epoch 247 Loss 0.0055
# Time taken for 1 epoch 2.719881534576416 sec
#
# Epoch 248 Batch 0 Loss 0.0030
# Epoch 248 Loss 0.0053
# Time taken for 1 epoch 2.9110844135284424 sec
#
# Epoch 249 Batch 0 Loss 0.0041
# Epoch 249 Loss 0.0053
# Time taken for 1 epoch 2.7307517528533936 sec
#
# Epoch 250 Batch 0 Loss 0.0033
# Epoch 250 Loss 0.0051
# Time taken for 1 epoch 2.9333672523498535 sec
#
# Epoch 251 Batch 0 Loss 0.0037
# Epoch 251 Loss 0.0052
# Time taken for 1 epoch 2.7075114250183105 sec
#
# Epoch 252 Batch 0 Loss 0.0038
# Epoch 252 Loss 0.0052
# Time taken for 1 epoch 2.9216160774230957 sec
#
# Epoch 253 Batch 0 Loss 0.0051
# Epoch 253 Loss 0.0053
# Time taken for 1 epoch 2.7118980884552 sec
#
# Epoch 254 Batch 0 Loss 0.0049
# Epoch 254 Loss 0.0051
# Time taken for 1 epoch 2.9164605140686035 sec
#
# Epoch 255 Batch 0 Loss 0.0039
# Epoch 255 Loss 0.0052
# Time taken for 1 epoch 2.7163310050964355 sec
#
# Epoch 256 Batch 0 Loss 0.0040
# Epoch 256 Loss 0.0050
# Time taken for 1 epoch 2.9506587982177734 sec
#
# Epoch 257 Batch 0 Loss 0.0036
# Epoch 257 Loss 0.0053
# Time taken for 1 epoch 2.7036709785461426 sec
#
# Epoch 258 Batch 0 Loss 0.0032
# Epoch 258 Loss 0.0052
# Time taken for 1 epoch 2.9238429069519043 sec
#
# Epoch 259 Batch 0 Loss 0.0045
# Epoch 259 Loss 0.0054
# Time taken for 1 epoch 2.743518352508545 sec
#
# Epoch 260 Batch 0 Loss 0.0046
# Epoch 260 Loss 0.0052
# Time taken for 1 epoch 2.9895718097686768 sec
#
# Epoch 261 Batch 0 Loss 0.0044
# Epoch 261 Loss 0.0051
# Time taken for 1 epoch 2.694247007369995 sec
#
# Epoch 262 Batch 0 Loss 0.0048
# Epoch 262 Loss 0.0051
# Time taken for 1 epoch 2.9684252738952637 sec
#
# Epoch 263 Batch 0 Loss 0.0038
# Epoch 263 Loss 0.0050
# Time taken for 1 epoch 2.685006856918335 sec
#
# Epoch 264 Batch 0 Loss 0.0042
# Epoch 264 Loss 0.0051
# Time taken for 1 epoch 2.9226653575897217 sec
#
# Epoch 265 Batch 0 Loss 0.0017
# Epoch 265 Loss 0.0049
# Time taken for 1 epoch 2.712275505065918 sec
#
# Epoch 266 Batch 0 Loss 0.0062
# Epoch 266 Loss 0.0052
# Time taken for 1 epoch 2.925563335418701 sec
#
# Epoch 267 Batch 0 Loss 0.0015
# Epoch 267 Loss 0.0051
# Time taken for 1 epoch 2.7398037910461426 sec
#
# Epoch 268 Batch 0 Loss 0.0028
# Epoch 268 Loss 0.0050
# Time taken for 1 epoch 3.2459824085235596 sec
#
# Epoch 269 Batch 0 Loss 0.0030
# Epoch 269 Loss 0.0050
# Time taken for 1 epoch 2.7097840309143066 sec
#
# Epoch 270 Batch 0 Loss 0.0058
# Epoch 270 Loss 0.0052
# Time taken for 1 epoch 2.9643781185150146 sec
#
# Epoch 271 Batch 0 Loss 0.0034
# Epoch 271 Loss 0.0051
# Time taken for 1 epoch 2.7118542194366455 sec
#
# Epoch 272 Batch 0 Loss 0.0052
# Epoch 272 Loss 0.0052
# Time taken for 1 epoch 2.92824649810791 sec
#
# Epoch 273 Batch 0 Loss 0.0041
# Epoch 273 Loss 0.0051
# Time taken for 1 epoch 2.7102043628692627 sec
#
# Epoch 274 Batch 0 Loss 0.0058
# Epoch 274 Loss 0.0052
# Time taken for 1 epoch 2.9239962100982666 sec
#
# Epoch 275 Batch 0 Loss 0.0031
# Epoch 275 Loss 0.0051
# Time taken for 1 epoch 2.706786632537842 sec
#
# Epoch 276 Batch 0 Loss 0.0024
# Epoch 276 Loss 0.0051
# Time taken for 1 epoch 2.9269802570343018 sec
#
# Epoch 277 Batch 0 Loss 0.0033
# Epoch 277 Loss 0.0050
# Time taken for 1 epoch 2.735990285873413 sec
#
# Epoch 278 Batch 0 Loss 0.0033
# Epoch 278 Loss 0.0051
# Time taken for 1 epoch 2.9703283309936523 sec
#
# Epoch 279 Batch 0 Loss 0.0041
# Epoch 279 Loss 0.0050
# Time taken for 1 epoch 2.688593626022339 sec
#
# Epoch 280 Batch 0 Loss 0.0049
# Epoch 280 Loss 0.0051
# Time taken for 1 epoch 2.9671812057495117 sec
#
# Epoch 281 Batch 0 Loss 0.0039
# Epoch 281 Loss 0.0050
# Time taken for 1 epoch 2.6977405548095703 sec
#
# Epoch 282 Batch 0 Loss 0.0035
# Epoch 282 Loss 0.0051
# Time taken for 1 epoch 2.9404687881469727 sec
#
# Epoch 283 Batch 0 Loss 0.0028
# Epoch 283 Loss 0.0048
# Time taken for 1 epoch 2.7336862087249756 sec
#
# Epoch 284 Batch 0 Loss 0.0042
# Epoch 284 Loss 0.0053
# Time taken for 1 epoch 2.943267345428467 sec
#
# Epoch 285 Batch 0 Loss 0.0033
# Epoch 285 Loss 0.0051
# Time taken for 1 epoch 2.7303121089935303 sec
#
# Epoch 286 Batch 0 Loss 0.0046
# Epoch 286 Loss 0.0052
# Time taken for 1 epoch 2.980879545211792 sec
#
# Epoch 287 Batch 0 Loss 0.0042
# Epoch 287 Loss 0.0050
# Time taken for 1 epoch 2.7008373737335205 sec
#
# Epoch 288 Batch 0 Loss 0.0034
# Epoch 288 Loss 0.0051
# Time taken for 1 epoch 2.919792652130127 sec
#
# Epoch 289 Batch 0 Loss 0.0039
# Epoch 289 Loss 0.0050
# Time taken for 1 epoch 2.736462116241455 sec
#
# Epoch 290 Batch 0 Loss 0.0040
# Epoch 290 Loss 0.0051
# Time taken for 1 epoch 2.9316577911376953 sec
#
# Epoch 291 Batch 0 Loss 0.0023
# Epoch 291 Loss 0.0051
# Time taken for 1 epoch 2.7127933502197266 sec
#
# Epoch 292 Batch 0 Loss 0.0036
# Epoch 292 Loss 0.0049
# Time taken for 1 epoch 2.967141628265381 sec
#
# Epoch 293 Batch 0 Loss 0.0044
# Epoch 293 Loss 0.0051
# Time taken for 1 epoch 2.706345796585083 sec
#
# Epoch 294 Batch 0 Loss 0.0050
# Epoch 294 Loss 0.0051
# Time taken for 1 epoch 2.9649860858917236 sec
#
# Epoch 295 Batch 0 Loss 0.0051
# Epoch 295 Loss 0.0049
# Time taken for 1 epoch 2.6992244720458984 sec
#
# Epoch 296 Batch 0 Loss 0.0037
# Epoch 296 Loss 0.0050
# Time taken for 1 epoch 2.933476448059082 sec
#
# Epoch 297 Batch 0 Loss 0.0030
# Epoch 297 Loss 0.0051
# Time taken for 1 epoch 2.7059218883514404 sec
#
# Epoch 298 Batch 0 Loss 0.0039
# Epoch 298 Loss 0.0051
# Time taken for 1 epoch 2.9025633335113525 sec
#
# Epoch 299 Batch 0 Loss 0.0054
# Epoch 299 Loss 0.0050
# Time taken for 1 epoch 2.7050111293792725 sec
#
# Epoch 300 Batch 0 Loss 0.0040
# Epoch 300 Loss 0.0049
# Time taken for 1 epoch 2.9521872997283936 sec
#
# Epoch 301 Batch 0 Loss 0.0038
# Epoch 301 Loss 0.0050
# Time taken for 1 epoch 2.724337339401245 sec
#
# Epoch 302 Batch 0 Loss 0.0035
# Epoch 302 Loss 0.0048
# Time taken for 1 epoch 2.9356117248535156 sec
#
# Epoch 303 Batch 0 Loss 0.0017
# Epoch 303 Loss 0.0050
# Time taken for 1 epoch 2.697202682495117 sec
#
# Epoch 304 Batch 0 Loss 0.0048
# Epoch 304 Loss 0.0050
# Time taken for 1 epoch 2.9340903759002686 sec
#
# Epoch 305 Batch 0 Loss 0.0036
# Epoch 305 Loss 0.0051
# Time taken for 1 epoch 2.7003142833709717 sec
#
# Epoch 306 Batch 0 Loss 0.0041
# Epoch 306 Loss 0.0051
# Time taken for 1 epoch 2.96402907371521 sec
#
# Epoch 307 Batch 0 Loss 0.0017
# Epoch 307 Loss 0.0075
# Time taken for 1 epoch 2.690128803253174 sec
#
# Epoch 308 Batch 0 Loss 0.0072
# Epoch 308 Loss 0.0475
# Time taken for 1 epoch 2.992053985595703 sec
#
# Epoch 309 Batch 0 Loss 0.0835
# Epoch 309 Loss 0.1496
# Time taken for 1 epoch 2.6966447830200195 sec
#
# Epoch 310 Batch 0 Loss 0.1165
# Epoch 310 Loss 0.1601
# Time taken for 1 epoch 2.945850133895874 sec
#
# Epoch 311 Batch 0 Loss 0.0810
# Epoch 311 Loss 0.1043
# Time taken for 1 epoch 2.6935441493988037 sec
#
# Epoch 312 Batch 0 Loss 0.0460
# Epoch 312 Loss 0.0544
# Time taken for 1 epoch 2.922093629837036 sec
#
# Epoch 313 Batch 0 Loss 0.0326
# Epoch 313 Loss 0.0288
# Time taken for 1 epoch 2.7251617908477783 sec
#
# Epoch 314 Batch 0 Loss 0.0157
# Epoch 314 Loss 0.0162
# Time taken for 1 epoch 2.926947593688965 sec
#
# Epoch 315 Batch 0 Loss 0.0079
# Epoch 315 Loss 0.0104
# Time taken for 1 epoch 2.7179114818573 sec
#
# Epoch 316 Batch 0 Loss 0.0064
# Epoch 316 Loss 0.0083
# Time taken for 1 epoch 2.930403709411621 sec
#
# Epoch 317 Batch 0 Loss 0.0069
# Epoch 317 Loss 0.0071
# Time taken for 1 epoch 2.763892412185669 sec
#
# Epoch 318 Batch 0 Loss 0.0050
# Epoch 318 Loss 0.0066
# Time taken for 1 epoch 2.9157164096832275 sec
#
# Epoch 319 Batch 0 Loss 0.0050
# Epoch 319 Loss 0.0067
# Time taken for 1 epoch 2.6904802322387695 sec
#
# Epoch 320 Batch 0 Loss 0.0038
# Epoch 320 Loss 0.0060
# Time taken for 1 epoch 2.9592196941375732 sec
#
# Epoch 321 Batch 0 Loss 0.0053
# Epoch 321 Loss 0.0061
# Time taken for 1 epoch 2.695436716079712 sec
#
# Epoch 322 Batch 0 Loss 0.0040
# Epoch 322 Loss 0.0056
# Time taken for 1 epoch 2.9949984550476074 sec
#
# Epoch 323 Batch 0 Loss 0.0061
# Epoch 323 Loss 0.0056
# Time taken for 1 epoch 2.7031850814819336 sec
#
# Epoch 324 Batch 0 Loss 0.0029
# Epoch 324 Loss 0.0056
# Time taken for 1 epoch 2.906970739364624 sec
#
# Epoch 325 Batch 0 Loss 0.0059
# Epoch 325 Loss 0.0056
# Time taken for 1 epoch 2.7197749614715576 sec
#
# Epoch 326 Batch 0 Loss 0.0040
# Epoch 326 Loss 0.0054
# Time taken for 1 epoch 2.9246580600738525 sec
#
# Epoch 327 Batch 0 Loss 0.0045
# Epoch 327 Loss 0.0053
# Time taken for 1 epoch 2.6904685497283936 sec
#
# Epoch 328 Batch 0 Loss 0.0051
# Epoch 328 Loss 0.0056
# Time taken for 1 epoch 3.0006425380706787 sec
#
# Epoch 329 Batch 0 Loss 0.0052
# Epoch 329 Loss 0.0052
# Time taken for 1 epoch 2.7091383934020996 sec
#
# Epoch 330 Batch 0 Loss 0.0052
# Epoch 330 Loss 0.0053
# Time taken for 1 epoch 2.9496076107025146 sec
#
# Epoch 331 Batch 0 Loss 0.0064
# Epoch 331 Loss 0.0053
# Time taken for 1 epoch 2.7103257179260254 sec
#
# Epoch 332 Batch 0 Loss 0.0062
# Epoch 332 Loss 0.0055
# Time taken for 1 epoch 2.922356605529785 sec
#
# Epoch 333 Batch 0 Loss 0.0052
# Epoch 333 Loss 0.0051
# Time taken for 1 epoch 2.7262253761291504 sec
#
# Epoch 334 Batch 0 Loss 0.0036
# Epoch 334 Loss 0.0051
# Time taken for 1 epoch 2.98311185836792 sec
#
# Epoch 335 Batch 0 Loss 0.0036
# Epoch 335 Loss 0.0052
# Time taken for 1 epoch 2.7090954780578613 sec
#
# Epoch 336 Batch 0 Loss 0.0061
# Epoch 336 Loss 0.0053
# Time taken for 1 epoch 2.909548282623291 sec
#
# Epoch 337 Batch 0 Loss 0.0050
# Epoch 337 Loss 0.0052
# Time taken for 1 epoch 2.692321538925171 sec
#
# Epoch 338 Batch 0 Loss 0.0038
# Epoch 338 Loss 0.0053
# Time taken for 1 epoch 2.9888756275177 sec
#
# Epoch 339 Batch 0 Loss 0.0043
# Epoch 339 Loss 0.0051
# Time taken for 1 epoch 2.6923909187316895 sec
#
# Epoch 340 Batch 0 Loss 0.0040
# Epoch 340 Loss 0.0056
# Time taken for 1 epoch 2.9065396785736084 sec
#
# Epoch 341 Batch 0 Loss 0.0047
# Epoch 341 Loss 0.0053
# Time taken for 1 epoch 2.710858106613159 sec
#
# Epoch 342 Batch 0 Loss 0.0046
# Epoch 342 Loss 0.0051
# Time taken for 1 epoch 2.91965913772583 sec
#
# Epoch 343 Batch 0 Loss 0.0044
# Epoch 343 Loss 0.0052
# Time taken for 1 epoch 2.730415105819702 sec
#
# Epoch 344 Batch 0 Loss 0.0035
# Epoch 344 Loss 0.0051
# Time taken for 1 epoch 2.916760206222534 sec
#
# Epoch 345 Batch 0 Loss 0.0033
# Epoch 345 Loss 0.0052
# Time taken for 1 epoch 2.7028696537017822 sec
#
# Epoch 346 Batch 0 Loss 0.0045
# Epoch 346 Loss 0.0051
# Time taken for 1 epoch 2.9072721004486084 sec
#
# Epoch 347 Batch 0 Loss 0.0047
# Epoch 347 Loss 0.0049
# Time taken for 1 epoch 2.7099034786224365 sec
#
# Epoch 348 Batch 0 Loss 0.0031
# Epoch 348 Loss 0.0050
# Time taken for 1 epoch 2.900214195251465 sec
#
# Epoch 349 Batch 0 Loss 0.0035
# Epoch 349 Loss 0.0051
# Time taken for 1 epoch 2.6914401054382324 sec
#
# Epoch 350 Batch 0 Loss 0.0057
# Epoch 350 Loss 0.0051
# Time taken for 1 epoch 2.9550764560699463 sec
#
# Epoch 351 Batch 0 Loss 0.0048
# Epoch 351 Loss 0.0051
# Time taken for 1 epoch 2.7239086627960205 sec
#
# Epoch 352 Batch 0 Loss 0.0021
# Epoch 352 Loss 0.0049
# Time taken for 1 epoch 2.9585373401641846 sec
#
# Epoch 353 Batch 0 Loss 0.0036
# Epoch 353 Loss 0.0051
# Time taken for 1 epoch 2.6984469890594482 sec
#
# Epoch 354 Batch 0 Loss 0.0048
# Epoch 354 Loss 0.0050
# Time taken for 1 epoch 2.941159963607788 sec
#
# Epoch 355 Batch 0 Loss 0.0038
# Epoch 355 Loss 0.0050
# Time taken for 1 epoch 2.714068651199341 sec
#
# Epoch 356 Batch 0 Loss 0.0035
# Epoch 356 Loss 0.0049
# Time taken for 1 epoch 2.9076855182647705 sec
#
# Epoch 357 Batch 0 Loss 0.0056
# Epoch 357 Loss 0.0050
# Time taken for 1 epoch 2.7201404571533203 sec
#
# Epoch 358 Batch 0 Loss 0.0050
# Epoch 358 Loss 0.0050
# Time taken for 1 epoch 2.9757542610168457 sec
#
# Epoch 359 Batch 0 Loss 0.0024
# Epoch 359 Loss 0.0049
# Time taken for 1 epoch 2.6989901065826416 sec
#
# Epoch 360 Batch 0 Loss 0.0037
# Epoch 360 Loss 0.0049
# Time taken for 1 epoch 2.9691479206085205 sec
#
# Epoch 361 Batch 0 Loss 0.0043
# Epoch 361 Loss 0.0049
# Time taken for 1 epoch 2.6914966106414795 sec
#
# Epoch 362 Batch 0 Loss 0.0046
# Epoch 362 Loss 0.0048
# Time taken for 1 epoch 5.341524362564087 sec
#
# Epoch 363 Batch 0 Loss 0.0057
# Epoch 363 Loss 0.0049
# Time taken for 1 epoch 2.7526838779449463 sec
#
# Epoch 364 Batch 0 Loss 0.0085
# Epoch 364 Loss 0.0051
# Time taken for 1 epoch 2.9607205390930176 sec
#
# Epoch 365 Batch 0 Loss 0.0030
# Epoch 365 Loss 0.0049
# Time taken for 1 epoch 2.7335381507873535 sec
#
# Epoch 366 Batch 0 Loss 0.0056
# Epoch 366 Loss 0.0050
# Time taken for 1 epoch 2.907525062561035 sec
#
# Epoch 367 Batch 0 Loss 0.0038
# Epoch 367 Loss 0.0047
# Time taken for 1 epoch 2.730639934539795 sec
#
# Epoch 368 Batch 0 Loss 0.0042
# Epoch 368 Loss 0.0051
# Time taken for 1 epoch 3.0021021366119385 sec
#
# Epoch 369 Batch 0 Loss 0.0054
# Epoch 369 Loss 0.0048
# Time taken for 1 epoch 2.686612844467163 sec
#
# Epoch 370 Batch 0 Loss 0.0040
# Epoch 370 Loss 0.0050
# Time taken for 1 epoch 2.9807236194610596 sec
#
# Epoch 371 Batch 0 Loss 0.0040
# Epoch 371 Loss 0.0051
# Time taken for 1 epoch 2.7169299125671387 sec
#
# Epoch 372 Batch 0 Loss 0.0047
# Epoch 372 Loss 0.0049
# Time taken for 1 epoch 2.918686628341675 sec
#
# Epoch 373 Batch 0 Loss 0.0055
# Epoch 373 Loss 0.0049
# Time taken for 1 epoch 2.7271904945373535 sec
#
# Epoch 374 Batch 0 Loss 0.0032
# Epoch 374 Loss 0.0049
# Time taken for 1 epoch 2.911301851272583 sec
#
# Epoch 375 Batch 0 Loss 0.0062
# Epoch 375 Loss 0.0049
# Time taken for 1 epoch 2.740966320037842 sec
#
# Epoch 376 Batch 0 Loss 0.0039
# Epoch 376 Loss 0.0049
# Time taken for 1 epoch 2.9583497047424316 sec
#
# Epoch 377 Batch 0 Loss 0.0038
# Epoch 377 Loss 0.0050
# Time taken for 1 epoch 2.702263116836548 sec
#
# Epoch 378 Batch 0 Loss 0.0065
# Epoch 378 Loss 0.0049
# Time taken for 1 epoch 2.9852218627929688 sec
#
# Epoch 379 Batch 0 Loss 0.0052
# Epoch 379 Loss 0.0051
# Time taken for 1 epoch 2.689669132232666 sec
#
# Epoch 380 Batch 0 Loss 0.0045
# Epoch 380 Loss 0.0047
# Time taken for 1 epoch 2.911317825317383 sec
#
# Epoch 381 Batch 0 Loss 0.0046
# Epoch 381 Loss 0.0048
# Time taken for 1 epoch 2.695631742477417 sec
#
# Epoch 382 Batch 0 Loss 0.0026
# Epoch 382 Loss 0.0048
# Time taken for 1 epoch 2.993405342102051 sec
#
# Epoch 383 Batch 0 Loss 0.0044
# Epoch 383 Loss 0.0048
# Time taken for 1 epoch 2.708624839782715 sec
#
# Epoch 384 Batch 0 Loss 0.0048
# Epoch 384 Loss 0.0050
# Time taken for 1 epoch 2.98989200592041 sec
#
# Epoch 385 Batch 0 Loss 0.0029
# Epoch 385 Loss 0.0048
# Time taken for 1 epoch 2.716421127319336 sec
#
# Epoch 386 Batch 0 Loss 0.0042
# Epoch 386 Loss 0.0048
# Time taken for 1 epoch 2.9089696407318115 sec
#
# Epoch 387 Batch 0 Loss 0.0030
# Epoch 387 Loss 0.0048
# Time taken for 1 epoch 2.7016232013702393 sec
#
# Epoch 388 Batch 0 Loss 0.0044
# Epoch 388 Loss 0.0049
# Time taken for 1 epoch 2.9264724254608154 sec
#
# Epoch 389 Batch 0 Loss 0.0040
# Epoch 389 Loss 0.0048
# Time taken for 1 epoch 2.7409684658050537 sec
#
# Epoch 390 Batch 0 Loss 0.0029
# Epoch 390 Loss 0.0048
# Time taken for 1 epoch 2.9125611782073975 sec
#
# Epoch 391 Batch 0 Loss 0.0040
# Epoch 391 Loss 0.0049
# Time taken for 1 epoch 2.6961328983306885 sec
#
# Epoch 392 Batch 0 Loss 0.0039
# Epoch 392 Loss 0.0049
# Time taken for 1 epoch 3.029552936553955 sec
#
# Epoch 393 Batch 0 Loss 0.0033
# Epoch 393 Loss 0.0048
# Time taken for 1 epoch 2.7008211612701416 sec
#
# Epoch 394 Batch 0 Loss 0.0050
# Epoch 394 Loss 0.0049
# Time taken for 1 epoch 2.9784626960754395 sec
#
# Epoch 395 Batch 0 Loss 0.0041
# Epoch 395 Loss 0.0048
# Time taken for 1 epoch 2.6924033164978027 sec
#
# Epoch 396 Batch 0 Loss 0.0029
# Epoch 396 Loss 0.0048
# Time taken for 1 epoch 2.9505858421325684 sec
#
# Epoch 397 Batch 0 Loss 0.0048
# Epoch 397 Loss 0.0047
# Time taken for 1 epoch 2.7175097465515137 sec
#
# Epoch 398 Batch 0 Loss 0.0031
# Epoch 398 Loss 0.0048
# Time taken for 1 epoch 2.92220139503479 sec
#
# Epoch 399 Batch 0 Loss 0.0023
# Epoch 399 Loss 0.0046
# Time taken for 1 epoch 2.7070655822753906 sec
#
# Epoch 400 Batch 0 Loss 0.0045
# Epoch 400 Loss 0.0047
# Time taken for 1 epoch 2.910555362701416 sec
#
# Epoch 401 Batch 0 Loss 0.0025
# Epoch 401 Loss 0.0046
# Time taken for 1 epoch 2.7178914546966553 sec
#
# Epoch 402 Batch 0 Loss 0.0039
# Epoch 402 Loss 0.0049
# Time taken for 1 epoch 2.9660041332244873 sec
#
# Epoch 403 Batch 0 Loss 0.0057
# Epoch 403 Loss 0.0049
# Time taken for 1 epoch 2.698251485824585 sec
#
# Epoch 404 Batch 0 Loss 0.0047
# Epoch 404 Loss 0.0049
# Time taken for 1 epoch 2.948503017425537 sec
#
# Epoch 405 Batch 0 Loss 0.0028
# Epoch 405 Loss 0.0048
# Time taken for 1 epoch 2.711540937423706 sec
#
# Epoch 406 Batch 0 Loss 0.0043
# Epoch 406 Loss 0.0047
# Time taken for 1 epoch 2.9876458644866943 sec
#
# Epoch 407 Batch 0 Loss 0.0053
# Epoch 407 Loss 0.0048
# Time taken for 1 epoch 2.694481372833252 sec
#
# Epoch 408 Batch 0 Loss 0.0019
# Epoch 408 Loss 0.0046
# Time taken for 1 epoch 2.928730010986328 sec
#
# Epoch 409 Batch 0 Loss 0.0043
# Epoch 409 Loss 0.0047
# Time taken for 1 epoch 2.7420623302459717 sec
#
# Epoch 410 Batch 0 Loss 0.0038
# Epoch 410 Loss 0.0048
# Time taken for 1 epoch 2.9592716693878174 sec
#
# Epoch 411 Batch 0 Loss 0.0050
# Epoch 411 Loss 0.0047
# Time taken for 1 epoch 2.6895265579223633 sec
#
# Epoch 412 Batch 0 Loss 0.0024
# Epoch 412 Loss 0.0044
# Time taken for 1 epoch 2.941605567932129 sec
#
# Epoch 413 Batch 0 Loss 0.0032
# Epoch 413 Loss 0.0049
# Time taken for 1 epoch 2.7473819255828857 sec
#
# Epoch 414 Batch 0 Loss 0.0039
# Epoch 414 Loss 0.0047
# Time taken for 1 epoch 2.9621684551239014 sec
#
# Epoch 415 Batch 0 Loss 0.0027
# Epoch 415 Loss 0.0047
# Time taken for 1 epoch 2.702972412109375 sec
#
# Epoch 416 Batch 0 Loss 0.0032
# Epoch 416 Loss 0.0048
# Time taken for 1 epoch 2.9362800121307373 sec
#
# Epoch 417 Batch 0 Loss 0.0015
# Epoch 417 Loss 0.0046
# Time taken for 1 epoch 2.718834638595581 sec
#
# Epoch 418 Batch 0 Loss 0.0039
# Epoch 418 Loss 0.0047
# Time taken for 1 epoch 2.9047605991363525 sec
#
# Epoch 419 Batch 0 Loss 0.0030
# Epoch 419 Loss 0.0048
# Time taken for 1 epoch 2.730132579803467 sec
#
# Epoch 420 Batch 0 Loss 0.0026
# Epoch 420 Loss 0.0048
# Time taken for 1 epoch 2.968679904937744 sec
#
# Epoch 421 Batch 0 Loss 0.0017
# Epoch 421 Loss 0.0047
# Time taken for 1 epoch 2.71287202835083 sec
#
# Epoch 422 Batch 0 Loss 0.0037
# Epoch 422 Loss 0.0048
# Time taken for 1 epoch 2.936582326889038 sec
#
# Epoch 423 Batch 0 Loss 0.0057
# Epoch 423 Loss 0.0048
# Time taken for 1 epoch 2.722947120666504 sec
#
# Epoch 424 Batch 0 Loss 0.0037
# Epoch 424 Loss 0.0045
# Time taken for 1 epoch 2.940762758255005 sec
#
# Epoch 425 Batch 0 Loss 0.0040
# Epoch 425 Loss 0.0048
# Time taken for 1 epoch 2.7027835845947266 sec
#
# Epoch 426 Batch 0 Loss 0.0064
# Epoch 426 Loss 0.0050
# Time taken for 1 epoch 2.936626672744751 sec
#
# Epoch 427 Batch 0 Loss 0.0028
# Epoch 427 Loss 0.0045
# Time taken for 1 epoch 2.681124448776245 sec
#
# Epoch 428 Batch 0 Loss 0.0032
# Epoch 428 Loss 0.0049
# Time taken for 1 epoch 2.9822592735290527 sec
#
# Epoch 429 Batch 0 Loss 0.0036
# Epoch 429 Loss 0.0048
# Time taken for 1 epoch 2.685692548751831 sec
#
# Epoch 430 Batch 0 Loss 0.0019
# Epoch 430 Loss 0.0049
# Time taken for 1 epoch 2.947026491165161 sec
#
# Epoch 431 Batch 0 Loss 0.0055
# Epoch 431 Loss 0.0050
# Time taken for 1 epoch 2.7050888538360596 sec
#
# Epoch 432 Batch 0 Loss 0.0042
# Epoch 432 Loss 0.0047
# Time taken for 1 epoch 2.990602493286133 sec
#
# Epoch 433 Batch 0 Loss 0.0037
# Epoch 433 Loss 0.0048
# Time taken for 1 epoch 2.6875128746032715 sec
#
# Epoch 434 Batch 0 Loss 0.0036
# Epoch 434 Loss 0.0047
# Time taken for 1 epoch 2.9481568336486816 sec
#
# Epoch 435 Batch 0 Loss 0.0055
# Epoch 435 Loss 0.0049
# Time taken for 1 epoch 2.7031352519989014 sec
#
# Epoch 436 Batch 0 Loss 0.0053
# Epoch 436 Loss 0.0048
# Time taken for 1 epoch 2.984219551086426 sec
#
# Epoch 437 Batch 0 Loss 0.0026
# Epoch 437 Loss 0.0045
# Time taken for 1 epoch 2.681504249572754 sec
#
# Epoch 438 Batch 0 Loss 0.0044
# Epoch 438 Loss 0.0048
# Time taken for 1 epoch 5.355659008026123 sec
#
# Epoch 439 Batch 0 Loss 0.0047
# Epoch 439 Loss 0.0046
# Time taken for 1 epoch 2.723385810852051 sec
#
# Epoch 440 Batch 0 Loss 0.0044
# Epoch 440 Loss 0.0048
# Time taken for 1 epoch 2.922605037689209 sec
#
# Epoch 441 Batch 0 Loss 0.0033
# Epoch 441 Loss 0.0045
# Time taken for 1 epoch 2.6954712867736816 sec
#
# Epoch 442 Batch 0 Loss 0.0034
# Epoch 442 Loss 0.0048
# Time taken for 1 epoch 2.9982995986938477 sec
#
# Epoch 443 Batch 0 Loss 0.0033
# Epoch 443 Loss 0.0046
# Time taken for 1 epoch 2.683924436569214 sec
#
# Epoch 444 Batch 0 Loss 0.0048
# Epoch 444 Loss 0.0048
# Time taken for 1 epoch 2.96795916557312 sec
#
# Epoch 445 Batch 0 Loss 0.0034
# Epoch 445 Loss 0.0046
# Time taken for 1 epoch 2.7283055782318115 sec
#
# Epoch 446 Batch 0 Loss 0.0039
# Epoch 446 Loss 0.0047
# Time taken for 1 epoch 2.946492910385132 sec
#
# Epoch 447 Batch 0 Loss 0.0041
# Epoch 447 Loss 0.0048
# Time taken for 1 epoch 2.7150161266326904 sec
#
# Epoch 448 Batch 0 Loss 0.0037
# Epoch 448 Loss 0.0047
# Time taken for 1 epoch 2.9996864795684814 sec
#
# Epoch 449 Batch 0 Loss 0.0037
# Epoch 449 Loss 0.0047
# Time taken for 1 epoch 2.6920676231384277 sec
#
# Epoch 450 Batch 0 Loss 0.0028
# Epoch 450 Loss 0.0047
# Time taken for 1 epoch 5.340995788574219 sec
#
# Epoch 451 Batch 0 Loss 0.0033
# Epoch 451 Loss 0.0047
# Time taken for 1 epoch 2.7492010593414307 sec
#
# Epoch 452 Batch 0 Loss 0.0024
# Epoch 452 Loss 0.0047
# Time taken for 1 epoch 2.9497528076171875 sec
#
# Epoch 453 Batch 0 Loss 0.0052
# Epoch 453 Loss 0.0046
# Time taken for 1 epoch 2.6978933811187744 sec
#
# Epoch 454 Batch 0 Loss 0.0040
# Epoch 454 Loss 0.0046
# Time taken for 1 epoch 2.9671056270599365 sec
#
# Epoch 455 Batch 0 Loss 0.0034
# Epoch 455 Loss 0.0048
# Time taken for 1 epoch 2.7172279357910156 sec
#
# Epoch 456 Batch 0 Loss 0.0049
# Epoch 456 Loss 0.0062
# Time taken for 1 epoch 2.904808521270752 sec
#
# Epoch 457 Batch 0 Loss 0.0056
# Epoch 457 Loss 0.0131
# Time taken for 1 epoch 2.722970724105835 sec
#
# Epoch 458 Batch 0 Loss 0.0097
# Epoch 458 Loss 0.0268
# Time taken for 1 epoch 2.9871413707733154 sec
#
# Epoch 459 Batch 0 Loss 0.0368
# Epoch 459 Loss 0.0503
# Time taken for 1 epoch 2.699216604232788 sec
#
# Epoch 460 Batch 0 Loss 0.0468
# Epoch 460 Loss 0.0691
# Time taken for 1 epoch 2.9137489795684814 sec
#
# Epoch 461 Batch 0 Loss 0.0591
# Epoch 461 Loss 0.0714
# Time taken for 1 epoch 2.695140838623047 sec
#
# Epoch 462 Batch 0 Loss 0.0441
# Epoch 462 Loss 0.0570
# Time taken for 1 epoch 2.9484031200408936 sec
#
# Epoch 463 Batch 0 Loss 0.0294
# Epoch 463 Loss 0.0330
# Time taken for 1 epoch 2.739086627960205 sec
#
# Epoch 464 Batch 0 Loss 0.0135
# Epoch 464 Loss 0.0189
# Time taken for 1 epoch 2.918872594833374 sec
#
# Epoch 465 Batch 0 Loss 0.0082
# Epoch 465 Loss 0.0118
# Time taken for 1 epoch 2.738032102584839 sec
#
# Epoch 466 Batch 0 Loss 0.0068
# Epoch 466 Loss 0.0088
# Time taken for 1 epoch 2.961106538772583 sec
#
# Epoch 467 Batch 0 Loss 0.0060
# Epoch 467 Loss 0.0084
# Time taken for 1 epoch 2.7132740020751953 sec
#
# Epoch 468 Batch 0 Loss 0.0046
# Epoch 468 Loss 0.0078
# Time taken for 1 epoch 2.9346752166748047 sec
#
# Epoch 469 Batch 0 Loss 0.0055
# Epoch 469 Loss 0.0068
# Time taken for 1 epoch 2.6874027252197266 sec
#
# Epoch 470 Batch 0 Loss 0.0048
# Epoch 470 Loss 0.0060
# Time taken for 1 epoch 3.0006048679351807 sec
#
# Epoch 471 Batch 0 Loss 0.0026
# Epoch 471 Loss 0.0057
# Time taken for 1 epoch 2.7089922428131104 sec
#
# Epoch 472 Batch 0 Loss 0.0044
# Epoch 472 Loss 0.0055
# Time taken for 1 epoch 2.93265962600708 sec
#
# Epoch 473 Batch 0 Loss 0.0052
# Epoch 473 Loss 0.0054
# Time taken for 1 epoch 2.7197577953338623 sec
#
# Epoch 474 Batch 0 Loss 0.0050
# Epoch 474 Loss 0.0054
# Time taken for 1 epoch 2.922758102416992 sec
#
# Epoch 475 Batch 0 Loss 0.0042
# Epoch 475 Loss 0.0052
# Time taken for 1 epoch 2.7130584716796875 sec
#
# Epoch 476 Batch 0 Loss 0.0044
# Epoch 476 Loss 0.0053
# Time taken for 1 epoch 2.9506003856658936 sec
#
# Epoch 477 Batch 0 Loss 0.0065
# Epoch 477 Loss 0.0053
# Time taken for 1 epoch 2.7109010219573975 sec
#
# Epoch 478 Batch 0 Loss 0.0051
# Epoch 478 Loss 0.0053
# Time taken for 1 epoch 2.921442985534668 sec
#
# Epoch 479 Batch 0 Loss 0.0052
# Epoch 479 Loss 0.0052
# Time taken for 1 epoch 2.7028121948242188 sec
#
# Epoch 480 Batch 0 Loss 0.0048
# Epoch 480 Loss 0.0050
# Time taken for 1 epoch 3.025439739227295 sec
#
# Epoch 481 Batch 0 Loss 0.0028
# Epoch 481 Loss 0.0049
# Time taken for 1 epoch 2.704059362411499 sec
#
# Epoch 482 Batch 0 Loss 0.0033
# Epoch 482 Loss 0.0051
# Time taken for 1 epoch 2.9164068698883057 sec
#
# Epoch 483 Batch 0 Loss 0.0031
# Epoch 483 Loss 0.0051
# Time taken for 1 epoch 2.7011125087738037 sec
#
# Epoch 484 Batch 0 Loss 0.0034
# Epoch 484 Loss 0.0050
# Time taken for 1 epoch 2.994748592376709 sec
#
# Epoch 485 Batch 0 Loss 0.0036
# Epoch 485 Loss 0.0050
# Time taken for 1 epoch 2.6860861778259277 sec
#
# Epoch 486 Batch 0 Loss 0.0054
# Epoch 486 Loss 0.0049
# Time taken for 1 epoch 2.916808843612671 sec
#
# Epoch 487 Batch 0 Loss 0.0050
# Epoch 487 Loss 0.0048
# Time taken for 1 epoch 2.699122190475464 sec
#
# Epoch 488 Batch 0 Loss 0.0015
# Epoch 488 Loss 0.0050
# Time taken for 1 epoch 2.926677942276001 sec
#
# Epoch 489 Batch 0 Loss 0.0041
# Epoch 489 Loss 0.0049
# Time taken for 1 epoch 2.7507073879241943 sec
#
# Epoch 490 Batch 0 Loss 0.0022
# Epoch 490 Loss 0.0047
# Time taken for 1 epoch 2.957700490951538 sec
#
# Epoch 491 Batch 0 Loss 0.0035
# Epoch 491 Loss 0.0047
# Time taken for 1 epoch 2.742133378982544 sec
#
# Epoch 492 Batch 0 Loss 0.0032
# Epoch 492 Loss 0.0046
# Time taken for 1 epoch 2.957756280899048 sec
#
# Epoch 493 Batch 0 Loss 0.0041
# Epoch 493 Loss 0.0049
# Time taken for 1 epoch 2.7009732723236084 sec
#
# Epoch 494 Batch 0 Loss 0.0043
# Epoch 494 Loss 0.0048
# Time taken for 1 epoch 2.9200384616851807 sec
#
# Epoch 495 Batch 0 Loss 0.0051
# Epoch 495 Loss 0.0047
# Time taken for 1 epoch 2.688755750656128 sec
#
# Epoch 496 Batch 0 Loss 0.0035
# Epoch 496 Loss 0.0049
# Time taken for 1 epoch 3.0438954830169678 sec
#
# Epoch 497 Batch 0 Loss 0.0030
# Epoch 497 Loss 0.0047
# Time taken for 1 epoch 2.7509117126464844 sec
#
# Epoch 498 Batch 0 Loss 0.0040
# Epoch 498 Loss 0.0048
# Time taken for 1 epoch 2.9159789085388184 sec
#
# Epoch 499 Batch 0 Loss 0.0032
# Epoch 499 Loss 0.0048
# Time taken for 1 epoch 2.6975409984588623 sec
#
# Epoch 500 Batch 0 Loss 0.0050
# Epoch 500 Loss 0.0047
# Time taken for 1 epoch 2.926607370376587 sec

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(7,7))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 10}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
from nltk.translate.bleu_score import sentence_bleu
def translate(sentence,reference):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

  res_arr=result.split(" ")
  res_arr.pop(-1)
  res_arr.pop(-1)

  print("res_arr", res_arr)
  
  ref_arr=reference.split(" ")
  ref_arr_arr=[]
  ref_arr_arr.append(ref_arr)
  print("ref_arr", ref_arr)
  print("ref_arr_arr", ref_arr_arr)

  score = sentence_bleu(ref_arr_arr, res_arr)
  print(score)

# %% [markdown]
# **Restore the latest checkpoint and test**

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate(u'the war is going in our favor.','')
# Out:
# Input: <start> the war is going in our favor . <end>
# Predicted translation: जग हमार हित म जा रहा ह। <end>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# res_arr ['जग', 'हमार', 'हित', 'म', 'जा', 'रहा', 'ह।']
# ref_arr ['']
# ref_arr_arr [['']]
# 0

# %%
translate(u'the war is going in our favor.','जग हमार हित म जा रहा है।')
# Out:
# Input: <start> the war is going in our favor . <end>
# Predicted translation: जग हमार हित म जा रहा ह। <end>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# res_arr ['जग', 'हमार', 'हित', 'म', 'जा', 'रहा', 'ह।']
# ref_arr ['जग', 'हमार', 'हित', 'म', 'जा', 'रहा', 'है।']
# ref_arr_arr [['जग', 'हमार', 'हित', 'म', 'जा', 'रहा', 'है।']]
# 0.8091067115702212

# %%
translate(u"he made such a long speech that we all got bored .",'')
# Out:
# Input: <start> he made such a long speech that we all got bored . <end>
# Predicted translation: उसन इतना लमबा भाषण दिया कि हम सब को बोर कर डाला। <end>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2313 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2349 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2359 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2339 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2342 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2313 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2349 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2359 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2339 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2342 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# res_arr ['उसन', 'इतना', 'लमबा', 'भाषण', 'दिया', 'कि', 'हम', 'सब', 'को', 'बोर', 'कर', 'डाला।']
# ref_arr ['']
# ref_arr_arr [['']]
# 0

# %%
translate(u"We're going home.",'हम घर जा रह हैं')
# Out:
# Input: <start> we re going home . <end>
# Predicted translation: हम घर जा रह ह। <end>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# res_arr ['हम', 'घर', 'जा', 'रह', 'ह।']
# ref_arr ['हम', 'घर', 'जा', 'रह', 'हैं']
# ref_arr_arr [['हम', 'घर', 'जा', 'रह', 'हैं']]
# 0.668740304976422

# %%
translate(u"Opinions vary from person to person.",'हर इनसान की सोच अलग होती है।')
# Out:
# Input: <start> opinions vary from person to person . <end>
# Predicted translation: हर इनसान की सोच अलग होती ह। <end>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# res_arr ['हर', 'इनसान', 'की', 'सोच', 'अलग', 'होती', 'ह।']
# ref_arr ['हर', 'इनसान', 'की', 'सोच', 'अलग', 'होती', 'है।']
# ref_arr_arr [['हर', 'इनसान', 'की', 'सोच', 'अलग', 'होती', 'है।']]
# 0.8091067115702212
